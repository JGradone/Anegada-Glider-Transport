# %%
# Imports
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.mpl.geoaxes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import pandas as pd
import numpy as np
import glob
import datetime
import xarray as xr
import gsw
import cmocean.cm as cmo

myFmtshort = mdates.DateFormatter('%m/%d\n%H:%M')
myFmtlong = mdates.DateFormatter('%y/%m/%d\n%H:%M')
myFmt = mdates.DateFormatter('%m/%d/%y')

# %% [markdown]
# ## Load data

# %%
fname = 'https://gamone.whoi.edu/thredds/dodsC/usgs/data0/bathy/ETOPO2v2c_f4.nc'
ds_etpo = xr.open_dataset(fname)
lonind = np.nanargmin(np.abs(ds_etpo.x.values+64.8))
depth_slice = ds_etpo.sel(x=ds_etpo.x.values[lonind],y=slice(17.7, 18.3))   # 17.85,18.11
depth_slice
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 10800, y: 5400)
# Coordinates:
#   * x        (x) float32 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 179.9 180.0
#   * y        (y) float32 -89.98 -89.95 -89.92 -89.88 ... 89.88 89.92 89.95 89.98
# Data variables:
#     z        (y, x) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:
#     source:                               -Rd -I2m -ZTLf                     ...
#     node_offset:  1

# %%
lonind = np.nanargmin(np.abs(ds_etpo.x.values+64.8))
depth_slice = ds_etpo.sel(x=ds_etpo.x.values[lonind],y=slice(17.7, 18.3))   # 17.85,18.11
depth_slice
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 18)
# Coordinates:
#     x        float32 -64.82
#   * y        (y) float32 17.72 17.75 17.78 17.82 ... 18.18 18.22 18.25 18.28
# Data variables:
#     z        (y) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:
#     source:                               -Rd -I2m -ZTLf                     ...
#     node_offset:  1

# %%
depth_slice.z.plot()
